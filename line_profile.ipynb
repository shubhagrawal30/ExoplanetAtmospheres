# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy import constants as c
from astropy import units as u
# %matplotlib widget

# %%
def parse_csv_file(filename, xunit, yunit):
    data = np.loadtxt(filename, delimiter=',', usecols=(0,1))
    return np.sort(data[:,0]) * xunit, data[:,1][np.argsort(data[:,0])] * yunit

# %%
jwst_wvs, jwst_flux = \
    parse_csv_file("./measurements/jwst_NaK.csv", u.micron, u.erg/u.s/u.cm**2/u.micron)
jwst_flux /= np.nanmax(jwst_flux)
plt.figure()
plt.plot(wvs, flux)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_wv = 1.15 * u.micron
upper_wv = 1.2 * u.micron
wvs, flux = jwst_wvs[(jwst_wvs > lower_wv) & (jwst_wvs < upper_wv)], jwst_flux[(jwst_wvs > lower_wv) & (jwst_wvs < upper_wv)]
plt.figure()
plt.plot(wvs, flux)
plt.xlabel("Wavelength (micron)")
plt.ylabel("Normalized Flux")
plt.title("Potassium Lines")
plt.grid()
plt.annotate("K", xy=(1.169, 0.4), xytext=(1.168, 0.5), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate("K", xy=(1.177, 0.4), xytext=(1.177, 0.5), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.savefig("./plots/pot1.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_wv = 1.235 * u.micron
upper_wv = 1.26 * u.micron
wvs, flux = jwst_wvs[(jwst_wvs > lower_wv) & (jwst_wvs < upper_wv)], jwst_flux[(jwst_wvs > lower_wv) & (jwst_wvs < upper_wv)]
plt.figure()
plt.plot(wvs, flux)
plt.xlabel("Wavelength (micron)")
plt.ylabel("Normalized Flux")
plt.title("Potassium Lines")
plt.grid()
plt.annotate("K", xy=(1.242, 0.6), xytext=(1.242, 0.64), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate("K", xy=(1.252, 0.6), xytext=(1.252, 0.64), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.savefig("./plots/pot2.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_wv = 1.12 * u.micron
upper_wv = 1.15 * u.micron
wvs, flux = jwst_wvs[(jwst_wvs > lower_wv) & (jwst_wvs < upper_wv)], jwst_flux[(jwst_wvs > lower_wv) & (jwst_wvs < upper_wv)]
plt.figure()
plt.plot(wvs, flux)
plt.xlabel("Wavelength (micron)")
plt.ylabel("Normalized Flux")
plt.title("Sodium Line")
plt.grid()
plt.annotate("Na", xy=(1.134, 0.35), xytext=(1.134, 0.38), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.savefig("./plots/sod.png")
plt.show()
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_87900\3091916162.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
